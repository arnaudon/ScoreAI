# %% [markdown]
# ### Test notebook

# %%
import numpy as np
a = np.random.uniform(0, 1, 10)
a
# Out:
# array([0.81745016, 0.93436081, 0.56418579, 0.97213577, 0.99972237,
#        0.0522849 , 0.9344    , 0.07903863, 0.43098448, 0.41112703])
